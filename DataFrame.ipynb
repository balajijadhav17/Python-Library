# %% [markdown]
# # Pandas Fuction

# %%
import pandas as pd

# %%
csv1=pd.read_csv("data1.csv")
csv1.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
csv1.index
# Out:
# RangeIndex(start=0, stop=2392, step=1)

# %%
print(csv1.columns)
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
csv1.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
csv1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %% [markdown]
# # DropNa and FillNa

# %%
csv1.head(25)
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0        1001   17       1          0                  2        19.833723
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# 5        1006   18       0          0                  1         8.191219
# 6        1007   15       0          1                  1        15.601680
# 7        1008   15       1          1                  4        15.424496
# 8        1009   17       0          0                  0         4.562008
# 9        1010   16       1          0                  1        18.444466
# 10       1011   17       0          0                  1        11.851364
# 11       1012   17       0          0                  1         7.598486
# ...

# %%
d1=pd.read_csv("data.csv")
d1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
d1.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
d1.head(50)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %%
d1.tail(50)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 119        60    103       124     332.7
# 120        30    112       137     193.9
# 121        45    100       120     100.7
# 122        60    119       169     336.7
# 123        60    107       127     344.9
# 124        60    111       151     368.5
# 125        60     98       122     271.0
# 126        60     97       124     275.3
# 127        60    109       127     382.0
# 128        90     99       125     466.4
# 129        60    114       151     384.0
# 130        60    104       134     342.5
# 131        60    107       138     357.5
# 132        60    103       133     335.0
# 133        60    106       132     327.5
# 134        60    103       136     339.0
# 135        20    136       156     189.0
# 136        45    117       143     317.7
# 137        45    115       137     318.0
# 138        45    113       138     308.0
# 139        20    141       162     222.4
# 140        60    108       135     390.0
# ...

# %%
d1[d1.isna().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
d1[d1.isna().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
d1[51:70]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 51        80    123       146     643.1
# 52        60    106       130     263.0
# 53        60    118       151     486.0
# 54        30    136       175     238.0
# 55        60    121       146     450.7
# 56        60    118       121     413.0
# 57        45    115       144     305.0
# 58        20    153       172     226.4
# 59        45    123       152     321.0
# 60       210    108       160    1376.0
# 61       160    110       137    1034.4
# 62       160    109       135     853.0
# 63        45    118       141     341.0
# 64        20    110       130     131.4
# 65       180     90       130     800.4
# 66       150    105       135     873.4
# 67       150    107       130     816.0
# 68        20    106       136     110.4
# 69       300    108       143    1500.2

# %%
d1.dropna()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
d1.head(50)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# ...

# %%
d2=d1.dropna()
print(d2)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
d2.head(50)
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 0         60    110       130     409.1
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# 22        60    130       101     300.0
# ...

# %%
d2[100:150]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 103        90     90       100     500.4
# 104        30     92       108      92.7
# 105        30     93       128     124.0
# 106       180     90       120     800.3
# 107        30     90       120      86.2
# 108        90     90       120     500.3
# 109       210    137       184    1860.4
# 110        60    102       124     325.2
# 111        45    107       124     275.0
# 112        15    124       139     124.2
# 113        45    100       120     225.3
# 114        60    108       131     367.6
# 115        60    108       151     351.7
# 116        60    116       141     443.0
# 117        60     97       122     277.4
# 119        60    103       124     332.7
# 120        30    112       137     193.9
# 121        45    100       120     100.7
# 122        60    119       169     336.7
# 123        60    107       127     344.9
# 124        60    111       151     368.5
# 125        60     98       122     271.0
# ...

# %%
d2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
d1[1:30]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 1         60    117       145     479.0
# 2         60    103       135     340.0
# 3         45    109       175     282.4
# 4         45    117       148     406.0
# 5         60    102       127     300.0
# 6         60    110       136     374.0
# 7         45    104       134     253.3
# 8         30    109       133     195.1
# 9         60     98       124     269.0
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112       NaN
# 18        60    103       123     323.0
# 19        45     97       125     243.0
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# 22        60    130       101     300.0
# ...

# %%
d3=d1.fillna("python")
d3
# Out:
#      Duration  Pulse  Maxpulse Calories
# 0          60    110       130    409.1
# 1          60    117       145    479.0
# 2          60    103       135    340.0
# 3          45    109       175    282.4
# 4          45    117       148    406.0
# ..        ...    ...       ...      ...
# 164        60    105       140    290.8
# 165        60    110       145    300.0
# 166        60    115       145    310.2
# 167        75    120       150    320.4
# 168        75    125       150    330.4
#
# [169 rows x 4 columns]

# %%
d3[1:30]
# Out:
#     Duration  Pulse  Maxpulse Calories
# 1         60    117       145    479.0
# 2         60    103       135    340.0
# 3         45    109       175    282.4
# 4         45    117       148    406.0
# 5         60    102       127    300.0
# 6         60    110       136    374.0
# 7         45    104       134    253.3
# 8         30    109       133    195.1
# 9         60     98       124    269.0
# 10        60    103       147    329.3
# 11        60    100       120    250.7
# 12        60    106       128    345.3
# 13        60    104       132    379.3
# 14        60     98       123    275.0
# 15        60     98       120    215.2
# 16        60    100       120    300.0
# 17        45     90       112   python
# 18        60    103       123    323.0
# 19        45     97       125    243.0
# 20        60    108       131    364.2
# 21        45    100       119    282.0
# 22        60    130       101    300.0
# 23        45    105       132    246.0
# ...

# %%
d=pd.read_csv("companydata.csv")
d
# Out:
#       Order_Number State_Code          Customer_Name  Order_Date      Status  \
# 0         139374.0         AP            Adhir Samal  11/01/2020   Delivered
# 1         139375.0         AP         Dannana Jhammi  11/01/2020   Delivered
# 2         139376.0         AS            Vipin Kumar  11/01/2020   Delivered
# 3         139377.0         BR          Ranjeet Kumar  11/01/2020   Delivered
# 4         139378.0         CG          Sajal Singhal  11/01/2020       Order
# ...            ...        ...                    ...         ...         ...
# 5105      144464.0         TN  Rahul Kumar Prajapati  31/12/2022   Delivered
# 5106      144465.0         TR             Sagar Jeur  31/12/2022     Shipped
# 5107      144466.0         UK        Rhushikesh Mane  31/12/2022       Order
# 5108      144467.0         UP           Ashish Kumar  31/12/2022  Processing
# 5109      144468.0         WB           Javed Akhter  31/12/2022   Delivered
#
# ...

# %%
d["Total_Cost"].sum()
# Out:
# 76383110.0

# %%
d["Total_Sales"].sum()
# Out:
# 99298043.0

# %%
d["Total_Sales"].max()
# Out:
# 75400.0

# %%
d["Total_Sales"].min()
# Out:
# 455.0

# %%
len(d['Brand'])
# Out:
# 5110

# %%
d[0:51]
# Out:
#     Order_Number State_Code            Customer_Name  Order_Date      Status  \
# 0       139374.0         AP              Adhir Samal  11/01/2020   Delivered
# 1       139375.0         AP           Dannana Jhammi  11/01/2020   Delivered
# 2       139376.0         AS              Vipin Kumar  11/01/2020   Delivered
# 3       139377.0         BR            Ranjeet Kumar  11/01/2020   Delivered
# 4       139378.0         CG            Sajal Singhal  11/01/2020       Order
# 5       139379.0         CG           Akhilesh Kumar  11/01/2020       Order
# 6       139380.0         CG     Suvankar Chakraborty  11/01/2020       Order
# 7            NaN        NaN                      NaN         NaN         NaN
# 8            NaN        NaN                      NaN         NaN         NaN
# 9       139381.0         CG        Suvankar Adhikary  12/01/2020       Order
# 10      139382.0         CG    Rahul Kumar Prajapati  13/01/2020       Order
# ...

# %%
d[d.isna().any(axis=1)]
# Out:
#      Order_Number State_Code Customer_Name Order_Date Status Product Category  \
# 7             NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 8             NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 12            NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 27            NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 45            NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 82            NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 127           NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 149           NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 150           NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 151           NaN        NaN           NaN        NaN    NaN     NaN      NaN
# 185           NaN        NaN           NaN        NaN    NaN     NaN      NaN
# ...

# %%
dd=d.dropna()
dd
# Out:
#       Order_Number State_Code          Customer_Name  Order_Date      Status  \
# 0         139374.0         AP            Adhir Samal  11/01/2020   Delivered
# 1         139375.0         AP         Dannana Jhammi  11/01/2020   Delivered
# 2         139376.0         AS            Vipin Kumar  11/01/2020   Delivered
# 3         139377.0         BR          Ranjeet Kumar  11/01/2020   Delivered
# 4         139378.0         CG          Sajal Singhal  11/01/2020       Order
# ...            ...        ...                    ...         ...         ...
# 5105      144464.0         TN  Rahul Kumar Prajapati  31/12/2022   Delivered
# 5106      144465.0         TR             Sagar Jeur  31/12/2022     Shipped
# 5107      144466.0         UK        Rhushikesh Mane  31/12/2022       Order
# 5108      144467.0         UP           Ashish Kumar  31/12/2022  Processing
# 5109      144468.0         WB           Javed Akhter  31/12/2022   Delivered
#
# ...

# %%
dd[dd.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Order_Number, State_Code, Customer_Name, Order_Date, Status, Product, Category, Brand, Cost, Sales, Quantity, Total_Cost, Total_Sales, Assigned Supervisor]
# Index: []

# %%
d
# Out:
#       Order_Number State_Code          Customer_Name  Order_Date      Status  \
# 0         139374.0         AP            Adhir Samal  11/01/2020   Delivered
# 1         139375.0         AP         Dannana Jhammi  11/01/2020   Delivered
# 2         139376.0         AS            Vipin Kumar  11/01/2020   Delivered
# 3         139377.0         BR          Ranjeet Kumar  11/01/2020   Delivered
# 4         139378.0         CG          Sajal Singhal  11/01/2020       Order
# ...            ...        ...                    ...         ...         ...
# 5105      144464.0         TN  Rahul Kumar Prajapati  31/12/2022   Delivered
# 5106      144465.0         TR             Sagar Jeur  31/12/2022     Shipped
# 5107      144466.0         UK        Rhushikesh Mane  31/12/2022       Order
# 5108      144467.0         UP           Ashish Kumar  31/12/2022  Processing
# 5109      144468.0         WB           Javed Akhter  31/12/2022   Delivered
#
# ...

# %%
ddd= d.fillna("6")
ddd
# Out:
#      Order_Number State_Code          Customer_Name  Order_Date      Status  \
# 0        139374.0         AP            Adhir Samal  11/01/2020   Delivered
# 1        139375.0         AP         Dannana Jhammi  11/01/2020   Delivered
# 2        139376.0         AS            Vipin Kumar  11/01/2020   Delivered
# 3        139377.0         BR          Ranjeet Kumar  11/01/2020   Delivered
# 4        139378.0         CG          Sajal Singhal  11/01/2020       Order
# ...           ...        ...                    ...         ...         ...
# 5105     144464.0         TN  Rahul Kumar Prajapati  31/12/2022   Delivered
# 5106     144465.0         TR             Sagar Jeur  31/12/2022     Shipped
# 5107     144466.0         UK        Rhushikesh Mane  31/12/2022       Order
# 5108     144467.0         UP           Ashish Kumar  31/12/2022  Processing
# 5109     144468.0         WB           Javed Akhter  31/12/2022   Delivered
#
# ...

# %%
ddd[195:250]
# Out:
#     Order_Number State_Code            Customer_Name  Order_Date      Status  \
# 195     139558.0         OR           Aditya Agarwal  27/03/2020       Order
# 196     139559.0         PB           Firdoush Jabee  27/03/2020  Processing
# 197            6          6                        6           6           6
# 198     139560.0         RJ        Jay Prakash Kumar  27/03/2020   Delivered
# 199     139561.0         SK            Ashish Pandey  27/03/2020     Shipped
# 200     139562.0         TN              Ajay Sharma  28/03/2020       Order
# 201     139563.0         TR          Moinuddin Saifi  28/03/2020  Processing
# 202     139564.0         UK  Ramkrishna Das Adhikary  28/03/2020   Delivered
# 203     139565.0         UP           Ranjeet Mandal  28/03/2020     Shipped
# 204     139566.0         UP           Ashwini Adsare  28/03/2020       Order
# 205     139567.0         UP            Rajesh Variya  28/03/2020  Processing
# ...
